# %% [markdown]
# <a href="https://colab.research.google.com/github/dftow01/dataengineering/blob/main/Assignment_1_Part_2_Web_Srapping_(Booking_com).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NAME : MUHAMMAD DANISH IQHWAN BIN ZAKARIA
# #MATRIC NO : A196191

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


def get_hotel_info(page):
    url = f'https://www.booking.com/searchresults.en-gb.html?ss=Kuala+Lumpur%2C+Kuala+Lumpur+Federal+Territory%2C+Malaysia&efdco=1&label=bra115jc-1DCAEoggI46AdIM1gDaKEBiAEBmAEJuAEHyAEM2AED6AEBiAIBqAIDuAKVvMq6BsACAdICJDNiNjRkNjNhLTVhODgtNDMyMS1hOTI5LTc1YTA2Y2VkYzdlNdgCBOACAQ&sid=8c6109f51b64dc2a1c4fbdd1c8ff750f&aid=2425901&lang=en-gb&sb=1&src_elem=sb&src=index&dest_id=-2403010&dest_type=city&ac_position=0&ac_click_type=b&ac_langcode=en&ac_suggestion_list_length=5&search_selected=true&search_pageview_id=ffac2fca71a80160&ac_meta=GhBmZmFjMmZjYTcxYTgwMTYwIAAoATICZW46Bkt1YWxhIEAASgBQAA%3D%3D&checkin=2025-01-30&checkout=2025-01-31&group_adults=2&no_rooms=1&group_children=0'

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36",
    }
    response = requests.get(url, headers=headers)

    soup = BeautifulSoup(response.content, 'html.parser')

    hotels = soup.find_all('div', class_='c066246e13 d8aec464ca')

    hotel_data = []
    for hotel in hotels:
        address_tag = hotel.find('span', {'data-testid': 'address'})
        room_tag = hotel.find('h4', class_='abf093bdfe e8f7c070a7')
        address = address_tag.text.strip() if address_tag else 'No address'
        room = room_tag.text.strip() if room_tag else 'No room'
        hotel_data.append([address, room])

    return hotel_data

all_hotels = []
for page in range(1, 6):
      print(f"Scraping page {page}")
      hotels = get_hotel_info(page)
      all_hotels.extend(hotels)
# Out:
# Scraping page 1
# Scraping page 2
# Scraping page 3
# Scraping page 4
# Scraping page 5

# %%
df = pd.DataFrame(all_hotels, columns=['Address', 'Room_Type'])
df
# Out:
#                                     Address                    Room_Type
# 0    Kuala Lumpur City-Centre, Kuala Lumpur        One-Bedroom Apartment
# 1             Golden Triangle, Kuala Lumpur  Cosmo Room Twin (No Window)
# 2    Kuala Lumpur City-Centre, Kuala Lumpur        One-Bedroom Apartment
# 3                              Kuala Lumpur           Standard King Room
# 4                  Mid Valley, Kuala Lumpur                     Standard
# ..                                      ...                          ...
# 120             Bukit Bintang, Kuala Lumpur            Urban Deluxe King
# 121               Brickfields, Kuala Lumpur                  King Studio
# 122  KL Sentral Train Station, Kuala Lumpur             Deluxe King Room
# 123             Bukit Bintang, Kuala Lumpur           Budget Double Room
# 124             Bangsar South, Kuala Lumpur             Deluxe Twin Room
#
# [125 rows x 2 columns]

# %%
# 1. Data Formatting: Convert all text to lowercase
df['Address'] = df['Address'].str.lower().str.strip()
df['Room_Type'] = df['Room_Type'].str.lower().str.strip()
df
# Out:
#                                     Address                    Room_Type
# 0    kuala lumpur city-centre, kuala lumpur        one-bedroom apartment
# 1             golden triangle, kuala lumpur  cosmo room twin (no window)
# 2    kuala lumpur city-centre, kuala lumpur        one-bedroom apartment
# 3                              kuala lumpur           standard king room
# 4                  mid valley, kuala lumpur                     standard
# ..                                      ...                          ...
# 120             bukit bintang, kuala lumpur            urban deluxe king
# 121               brickfields, kuala lumpur                  king studio
# 122  kl sentral train station, kuala lumpur             deluxe king room
# 123             bukit bintang, kuala lumpur           budget double room
# 124             bangsar south, kuala lumpur             deluxe twin room
#
# [125 rows x 2 columns]

# %%
# 2. Remove duplicate rows based on the 'Address' and 'Room_Type' columns
df_cleaned = df.drop_duplicates(subset=['Address', 'Room_Type'], keep='first')
print("\nCleaned DataFrame:")
df_cleaned
# Out:
# Cleaned DataFrame:
#                                     Address  \
# 0    kuala lumpur city-centre, kuala lumpur
# 1             golden triangle, kuala lumpur
# 3                              kuala lumpur
# 4                  mid valley, kuala lumpur
# 6               bukit bintang, kuala lumpur
# 7                  mid valley, kuala lumpur
# 8               bukit bintang, kuala lumpur
# 9                              kuala lumpur
# 10   kuala lumpur city-centre, kuala lumpur
# 11   kuala lumpur city-centre, kuala lumpur
# 12                   chow kit, kuala lumpur
# 13              bangsar south, kuala lumpur
# 14              bukit bintang, kuala lumpur
# 15                 mont kiara, kuala lumpur
# 16              bukit bintang, kuala lumpur
# 17                brickfields, kuala lumpur
# 18                       pudu, kuala lumpur
# 19   kuala lumpur city-centre, kuala lumpur
# 20   kl sentral train station, kuala lumpur
# 21              bukit bintang, kuala lumpur
# ...

# %%
df_cleaned.to_csv('scraped_hotel_data_cleaned.csv', index=False)

print("Data scraped and saved to scraped_hotel_data_cleaned.csv")
# Out:
# Data scraped and saved to scraped_hotel_data_cleaned.csv
